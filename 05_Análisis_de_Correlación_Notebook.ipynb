# %% [markdown]
# ## Introducción y Carga de Datos
#
# Este notebook demuestra cómo calcular los coeficientes de correlación de Pearson para un conjunto de datos que incluye ventas y gastos en publicidad.

# %%
### Importar Librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### Carga de Datos
# Cargar el dataset
ruta = '05_dataset_correlacion_csv.csv'
df = pd.read_csv(ruta,  header='infer', sep=',')
# Mostrar las primeras filas del dataset
tipos = df.dtypes
display(tipos)
# Out:
# Periodo         object
# ventas_1         int64
# publicidad_1     int64
# ventas_2         int64
# publicidad_2     int64
# ventas_3         int64
# publicidad_3     int64
# dtype: object

# %% [markdown]
# ## Análisis de Correlación
#
# Calcularemos los coeficientes de correlación para cada par de variables relacionadas con ventas y publicidad.

# %%
### Cálculo de Correlaciones
# Calcular los coeficientes de correlación de Pearson
corr_e1 = df['ventas_1'].corr(df['publicidad_1'])
corr_e2 = df['ventas_2'].corr(df['publicidad_2'])
corr_e3 = df['ventas_3'].corr(df['publicidad_3'])

display(corr_e1)
display(corr_e2)
display(corr_e3)
# Out:
# -0.02330308864609186
# 0.8763996839555259
# -0.9950333043724009

# %% [markdown]
# ## Visualización
#
# En esta sección, crearemos visualizaciones para entender mejor las correlaciones.

# %%
### Gráficos de Dispersión
# Ejemplo de un gráfico de dispersión

sns.scatterplot(data=df, x='ventas_1', y='publicidad_1')
plt.title('Relación entre Ventas 1 y Publicidad 1')
plt.show()
